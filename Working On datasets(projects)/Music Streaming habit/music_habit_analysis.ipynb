# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('music_streaming_habits_2026.csv')

# %%
df
# Out:
#       listener_id  age    country       platform subscription  top_genre  \
# 0               1   24  Australia    Apple Music         Free        R&B
# 1               2   21    Germany        Spotify         Free  Classical
# 2               3   32      Japan   Amazon Music         Free    Hip-Hop
# 3               4   39      Japan    Apple Music         Free        Pop
# 4               5   23      India        Spotify       Family    Country
# ...           ...  ...        ...            ...          ...        ...
# 3995         3996   26     France        Spotify       Family        Pop
# 3996         3997   35    Germany  YouTube Music         Free       Rock
# 3997         3998   43      India    Apple Music         Free    Hip-Hop
# 3998         3999   26      India    Apple Music      Student      Indie
# 3999         4000   24         UK        Spotify      Premium    Hip-Hop
#
#           top_artist  daily_listening_minutes  songs_per_day  playlists_count  \
# ...

# %%
df.head()
# Out:
#    listener_id  age    country      platform subscription  top_genre  \
# 0            1   24  Australia   Apple Music         Free        R&B
# 1            2   21    Germany       Spotify         Free  Classical
# 2            3   32      Japan  Amazon Music         Free    Hip-Hop
# 3            4   39      Japan   Apple Music         Free        Pop
# 4            5   23      India       Spotify       Family    Country
#
#        top_artist  daily_listening_minutes  songs_per_day  playlists_count  \
# 0  Kendrick Lamar                      191             54                9
# 1           Drake                      249             68               10
# 2  Olivia Rodrigo                       49             11               11
# 3       Burna Boy                       96             22                8
# 4  Olivia Rodrigo                      100             24               13
#
#    skip_rate_pct  discover_weekly_user top_mood  uses_offline_mode  \
# ...

# %%
df1 = df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   listener_id              4000 non-null   int64
#  1   age                      4000 non-null   int64
#  2   country                  4000 non-null   object
#  3   platform                 4000 non-null   object
#  4   subscription             4000 non-null   object
#  5   top_genre                4000 non-null   object
#  6   top_artist               4000 non-null   object
#  7   daily_listening_minutes  4000 non-null   int64
#  8   songs_per_day            4000 non-null   int64
#  9   playlists_count          4000 non-null   int64
#  10  skip_rate_pct            4000 non-null   float64
#  11  discover_weekly_user     4000 non-null   bool
#  12  top_mood                 4000 non-null   object
#  13  uses_offline_mode        4000 non-null   bool
# ...

# %%
df.describe()
# Out:
#        listener_id          age  daily_listening_minutes  songs_per_day  \
# count  4000.000000  4000.000000              4000.000000    4000.000000
# mean   2000.500000    27.849000               138.702750      39.137500
# std    1154.844867     8.595881                86.296023      25.046296
# min       1.000000    13.000000                 5.000000       1.000000
# 25%    1000.750000    22.000000                74.000000      21.000000
# 50%    2000.500000    28.000000               122.000000      35.000000
# 75%    3000.250000    34.000000               185.000000      52.250000
# max    4000.000000    57.000000               697.000000     198.000000
#
#        playlists_count  skip_rate_pct
# count      4000.000000    4000.000000
# mean          8.994500      28.163375
# std           3.027914      11.815850
# min           1.000000       0.000000
# 25%           7.000000      20.000000
# 50%           9.000000      28.100000
# 75%          11.000000      36.300000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.value_counts()
# Out:
# listener_id  age  country    platform       subscription  top_genre  top_artist         daily_listening_minutes  songs_per_day  playlists_count  skip_rate_pct  discover_weekly_user  top_mood   uses_offline_mode  podcasts_too
# 1            24   Australia  Apple Music    Free          R&B        Kendrick Lamar     191                      54             9                39.3           False                 Sleep      False              True            1
# 2672         18   Australia  YouTube Music  Family        Rock       Olivia Rodrigo     64                       29             7                11.3           False                 Workout    True               False           1
# 2659         32   Japan      Spotify        Student       Hip-Hop    Tyler the Creator  29                       4              7                25.7           False                 Workout    True               False           1
# ...

# %%
df['country'].value_counts()
# Out:
# country
# Japan        439
# Canada       429
# USA          418
# Brazil       409
# Nigeria      401
# Australia    397
# India        390
# France       377
# Germany      371
# UK           369
# Name: count, dtype: int64

# %%
df['platform'].unique()
# Out:
# array(['Apple Music', 'Spotify', 'Amazon Music', 'Tidal', 'SoundCloud',
#        'YouTube Music'], dtype=object)

# %%
for i in df.columns:
    print(f"{i}: {df[i].unique()} unique values \n")
# Out:
# listener_id: [   1    2    3 ... 3998 3999 4000] unique values
#
# age: [24 21 32 39 23 41 13 22 40 27 31 30 50 28 37 20 15 26 38 34 25 16 17 35
#  14 42 43 44 29 33 19 18 36 48 47 45 56 46 49 52 51 53 55 57] unique values
#
# country: ['Australia' 'Germany' 'Japan' 'India' 'Nigeria' 'Canada' 'USA' 'UK'
#  'Brazil' 'France'] unique values
#
# platform: ['Apple Music' 'Spotify' 'Amazon Music' 'Tidal' 'SoundCloud'
#  'YouTube Music'] unique values
#
# subscription: ['Free' 'Family' 'Premium' 'Student'] unique values
#
# top_genre: ['R&B' 'Classical' 'Hip-Hop' 'Pop' 'Country' 'Rock' 'EDM' 'Jazz' 'Lo-fi'
#  'K-Pop' 'Afrobeats' 'Indie'] unique values
#
# top_artist: ['Kendrick Lamar' 'Drake' 'Olivia Rodrigo' 'Burna Boy' 'Bad Bunny' 'SZA'
#  'Taylor Swift' 'Travis Scott' 'Billie Eilish' 'The Weeknd' 'BTS'
#  'Dua Lipa' 'Tyler the Creator' 'Ariana Grande'] unique values
#
# daily_listening_minutes: [191 249  49  96 100  64 193 142 120 127 255 481 330 107  54  75 288  39
# ...

# %%
df.drop('listener_id' , axis = 1, inplace = True)

# %%
df
# Out:
#       age    country       platform subscription  top_genre      top_artist  \
# 0      24  Australia    Apple Music         Free        R&B  Kendrick Lamar
# 1      21    Germany        Spotify         Free  Classical           Drake
# 2      32      Japan   Amazon Music         Free    Hip-Hop  Olivia Rodrigo
# 3      39      Japan    Apple Music         Free        Pop       Burna Boy
# 4      23      India        Spotify       Family    Country  Olivia Rodrigo
# ...   ...        ...            ...          ...        ...             ...
# 3995   26     France        Spotify       Family        Pop             SZA
# 3996   35    Germany  YouTube Music         Free       Rock   Ariana Grande
# 3997   43      India    Apple Music         Free    Hip-Hop        Dua Lipa
# 3998   26      India    Apple Music      Student      Indie             SZA
# 3999   24         UK        Spotify      Premium    Hip-Hop        Dua Lipa
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
df.drop('top_artist' , axis = 1, inplace = True)

# %%
df
# Out:
#       age    country       platform subscription  top_genre  \
# 0      24  Australia    Apple Music         Free        R&B
# 1      21    Germany        Spotify         Free  Classical
# 2      32      Japan   Amazon Music         Free    Hip-Hop
# 3      39      Japan    Apple Music         Free        Pop
# 4      23      India        Spotify       Family    Country
# ...   ...        ...            ...          ...        ...
# 3995   26     France        Spotify       Family        Pop
# 3996   35    Germany  YouTube Music         Free       Rock
# 3997   43      India    Apple Music         Free    Hip-Hop
# 3998   26      India    Apple Music      Student      Indie
# 3999   24         UK        Spotify      Premium    Hip-Hop
#
#       daily_listening_minutes  songs_per_day  playlists_count  skip_rate_pct  \
# 0                         191             54                9           39.3
# 1                         249             68               10           18.3
# ...

# %%
X = df.drop('daily_listening_minutes' , axis = 1)
y = df1['daily_listening_minutes']

# %%
X
# Out:
#       age    country       platform subscription  top_genre  songs_per_day  \
# 0      24  Australia    Apple Music         Free        R&B             54
# 1      21    Germany        Spotify         Free  Classical             68
# 2      32      Japan   Amazon Music         Free    Hip-Hop             11
# 3      39      Japan    Apple Music         Free        Pop             22
# 4      23      India        Spotify       Family    Country             24
# ...   ...        ...            ...          ...        ...            ...
# 3995   26     France        Spotify       Family        Pop             55
# 3996   35    Germany  YouTube Music         Free       Rock             77
# 3997   43      India    Apple Music         Free    Hip-Hop             38
# 3998   26      India    Apple Music      Student      Indie             31
# 3999   24         UK        Spotify      Premium    Hip-Hop             49
#
# ...

# %%
y
# Out:
# 0       191
# 1       249
# 2        49
# 3        96
# 4       100
#        ...
# 3995    197
# 3996    320
# 3997     99
# 3998     76
# 3999    161
# Name: daily_listening_minutes, Length: 4000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)

# %%
print(X_train.shape)
# Out:
# (2800, 12)

# %%
print(X_test.shape)
# Out:
# (1200, 12)
