# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('insurance.csv')

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
sns.distplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.boxplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
col_name = []
for col in df.columns:
    col_name.append(col)
print(col_name)
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']

# %%
for i in col_name:
    plt.figure(figsize=(12,10))
    sns.boxplot(x = df[i])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
df['bmi']
# Out:
# 0       27.900
# 1       33.770
# 2       33.000
# 3       22.705
# 4       28.880
#          ...
# 1333    30.970
# 1334    31.920
# 1335    36.850
# 1336    25.800
# 1337    29.070
# Name: bmi, Length: 1337, dtype: float64

# %%
sns.distplot(df['bmi'])
# Out:
# <Axes: xlabel='bmi', ylabel='Density'>

# %%
sns.boxplot(df['bmi'])
# Out:
# <Axes: ylabel='bmi'>

# %%
sns.violinplot(df['bmi'])
# Out:
# <Axes: ylabel='bmi'>

# %%
mean = df['bmi'].mean()

# %%
mean
# Out:
# 30.66345175766642

# %%
# IQR > IMPUTAION OF THE OUTLIER

# %%
Q3 = df['bmi'].quantile(0.75)
Q1 = df['bmi'].quantile(0.25)

# %%
Q3
# Out:
# 34.7

# %%
Q1
# Out:
# 26.29

# %%
IQR = Q3 - Q1

upper_fence = Q3 + 1.5*IQR
lower_fence = Q1 - 1.5*IQR

# %%
# IMPUTE

# %%
df['bmi'] = np.where(
    (df['bmi'] < lower_fence) | (df['bmi'] > upper_fence),
    mean,
    df['bmi']
)

# %%
sns.boxplot(df['bmi'])
# Out:
# <Axes: ylabel='bmi'>

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
df['smoker'].value_counts()
# Out:
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64

# %%
ord = OrdinalEncoder()

# %%
df['smoker']= ord.fit_transform(df[['smoker']])

# %%
df
# Out:
#       age     sex     bmi  children  smoker     region      charges
# 0      19  female  27.900         0     1.0  southwest  16884.92400
# 1      18    male  33.770         1     0.0  southeast   1725.55230
# 2      28    male  33.000         3     0.0  southeast   4449.46200
# 3      33    male  22.705         0     0.0  northwest  21984.47061
# 4      32    male  28.880         0     0.0  northwest   3866.85520
# ...   ...     ...     ...       ...     ...        ...          ...
# 1333   50    male  30.970         3     0.0  northwest  10600.54830
# 1334   18  female  31.920         0     0.0  northeast   2205.98080
# 1335   18  female  36.850         0     0.0  southeast   1629.83350
# 1336   21  female  25.800         0     0.0  southwest   2007.94500
# 1337   61  female  29.070         0     1.0  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: count, dtype: int64

# %%
df['region'] = ord.fit_transform(df[['region']])

# %%
df
# Out:
#       age     sex     bmi  children  smoker  region      charges
# 0      19  female  27.900         0     1.0     3.0  16884.92400
# 1      18    male  33.770         1     0.0     2.0   1725.55230
# 2      28    male  33.000         3     0.0     2.0   4449.46200
# 3      33    male  22.705         0     0.0     1.0  21984.47061
# 4      32    male  28.880         0     0.0     1.0   3866.85520
# ...   ...     ...     ...       ...     ...     ...          ...
# 1333   50    male  30.970         3     0.0     1.0  10600.54830
# 1334   18  female  31.920         0     0.0     0.0   2205.98080
# 1335   18  female  36.850         0     0.0     2.0   1629.83350
# 1336   21  female  25.800         0     0.0     3.0   2007.94500
# 1337   61  female  29.070         0     1.0     1.0  29141.36030
#
# [1337 rows x 7 columns]

# %%
df['region'].value_counts()
# Out:
# region
# 2.0    364
# 3.0    325
# 1.0    324
# 0.0    324
# Name: count, dtype: int64

# %%
df
# Out:
#       age     sex     bmi  children  smoker  region      charges
# 0      19  female  27.900         0     1.0     3.0  16884.92400
# 1      18    male  33.770         1     0.0     2.0   1725.55230
# 2      28    male  33.000         3     0.0     2.0   4449.46200
# 3      33    male  22.705         0     0.0     1.0  21984.47061
# 4      32    male  28.880         0     0.0     1.0   3866.85520
# ...   ...     ...     ...       ...     ...     ...          ...
# 1333   50    male  30.970         3     0.0     1.0  10600.54830
# 1334   18  female  31.920         0     0.0     0.0   2205.98080
# 1335   18  female  36.850         0     0.0     2.0   1629.83350
# 1336   21  female  25.800         0     0.0     3.0   2007.94500
# 1337   61  female  29.070         0     1.0     1.0  29141.36030
#
# [1337 rows x 7 columns]

# %%
df['sex'] = ord.fit_transform(df[['sex']])

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19  0.0  27.900         0     1.0     3.0  16884.92400
# 1      18  1.0  33.770         1     0.0     2.0   1725.55230
# 2      28  1.0  33.000         3     0.0     2.0   4449.46200
# 3      33  1.0  22.705         0     0.0     1.0  21984.47061
# 4      32  1.0  28.880         0     0.0     1.0   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50  1.0  30.970         3     0.0     1.0  10600.54830
# 1334   18  0.0  31.920         0     0.0     0.0   2205.98080
# 1335   18  0.0  36.850         0     0.0     2.0   1629.83350
# 1336   21  0.0  25.800         0     0.0     3.0   2007.94500
# 1337   61  0.0  29.070         0     1.0     1.0  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19  0.0  27.900         0     1.0     3.0  16884.92400
# 1      18  1.0  33.770         1     0.0     2.0   1725.55230
# 2      28  1.0  33.000         3     0.0     2.0   4449.46200
# 3      33  1.0  22.705         0     0.0     1.0  21984.47061
# 4      32  1.0  28.880         0     0.0     1.0   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50  1.0  30.970         3     0.0     1.0  10600.54830
# 1334   18  0.0  31.920         0     0.0     0.0   2205.98080
# 1335   18  0.0  36.850         0     0.0     2.0   1629.83350
# 1336   21  0.0  25.800         0     0.0     3.0   2007.94500
# 1337   61  0.0  29.070         0     1.0     1.0  29141.36030
#
# [1337 rows x 7 columns]

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19  0.0  27.900         0     1.0     3.0  16884.92400
# 1      18  1.0  33.770         1     0.0     2.0   1725.55230
# 2      28  1.0  33.000         3     0.0     2.0   4449.46200
# 3      33  1.0  22.705         0     0.0     1.0  21984.47061
# 4      32  1.0  28.880         0     0.0     1.0   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50  1.0  30.970         3     0.0     1.0  10600.54830
# 1334   18  0.0  31.920         0     0.0     0.0   2205.98080
# 1335   18  0.0  36.850         0     0.0     2.0   1629.83350
# 1336   21  0.0  25.800         0     0.0     3.0   2007.94500
# 1337   61  0.0  29.070         0     1.0     1.0  29141.36030
#
# [1337 rows x 7 columns]

# %%
X = df.drop('charges' , axis = 1)

# %%
y = df['charges']

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1337, dtype: float64

# %%
X
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19  0.0  27.900         0     1.0     3.0
# 1      18  1.0  33.770         1     0.0     2.0
# 2      28  1.0  33.000         3     0.0     2.0
# 3      33  1.0  22.705         0     0.0     1.0
# 4      32  1.0  28.880         0     0.0     1.0
# ...   ...  ...     ...       ...     ...     ...
# 1333   50  1.0  30.970         3     0.0     1.0
# 1334   18  0.0  31.920         0     0.0     0.0
# 1335   18  0.0  36.850         0     0.0     2.0
# 1336   21  0.0  25.800         0     0.0     3.0
# 1337   61  0.0  29.070         0     1.0     1.0
#
# [1337 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test , y_train , y_test = train_test_split(X,y,test_size=0.3 , random_state=1)

# %%
X_train.shape
# Out:
# (935, 6)

# %%
X_test.shape
# Out:
# (402, 6)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import Lasso , Ridge , LinearRegression

# %%
Lass = Lasso()

# %%
Lass
# Out:
# Lasso()

# %%
parms = {'alpha' : [00.1 , 0.01 , 0.1, 0.5 , .75]}

# %%
grid = GridSearchCV(Lass , param_grid=parms , scoring='r2', verbose=2)

# %%
grid
# Out:
# GridSearchCV(estimator=Lasso(),
#              param_grid={'alpha': [0.1, 0.01, 0.1, 0.5, 0.75]}, scoring='r2',
#              verbose=2)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# ...

# %%
grid.best_estimator_
# Out:
# Lasso(alpha=0.75)

# %%
grid.best_params_
# Out:
# {'alpha': 0.75}

# %%
y = grid.best_estimator_.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test , y)
# Out:
# 0.7370738375494859

# %%
lin = LinearRegression()

# %%
lin.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
yy = lin.predict(X_test)

# %%
r2_score(y_test,yy)
# Out:
# 0.7370678165977901

# %%
X_train_drop = X_train.drop('region' , axis = 1)

# %%
X_test_drop = X_test.drop('region' , axis = 1)

# %%
X_train_drop
# Out:
#       age  sex     bmi  children  smoker
# 520    50  0.0  27.360         0     0.0
# 575    58  0.0  27.170         0     0.0
# 770    61  1.0  36.100         3     0.0
# 314    27  0.0  31.400         0     1.0
# 426    38  0.0  27.265         1     0.0
# ...   ...  ...     ...       ...     ...
# 716    49  0.0  22.610         1     0.0
# 906    27  1.0  32.585         3     0.0
# 1097   22  1.0  33.770         0     0.0
# 235    40  0.0  22.220         2     1.0
# 1062   59  1.0  41.140         1     1.0
#
# [935 rows x 5 columns]

# %%
grid.best_estimator_.fit(X_train_drop,y_train)
# Out:
# Lasso(alpha=0.75)

# %%
yy = grid.best_estimator_.predict(X_test_drop)

# %%
X_test_drop.shape
# Out:
# (402, 5)

# %%
r2_score(y_test , yy)
# Out:
# 0.7359110090735826
